# %%
#Import TwitterAPI
from TwitterAPI import TwitterAPI

#Consumer and Access Keys
consumer_key = ""
consumer_secret = ""
access_token_key = ""
access_token_secret = ""

print("Consumer and access keys and secrets added")

#Keywords as dictioanry
keywords = {
    'germany':'\u0623\u0644\u0645\u0627\u0646\u064a\u0627', 
    'greece':'\u064a\u0648\u0646\u0627\u0646',
    'sweden': '\u0627\u0644\u0633\u0648\u064a\u062f',
    'austria': '\u0627\u0644\u0646\u0645\u0633\u0627',
    'uk': '\u0627\u0644\u0645\u0645\u0644\u0643\u0629 \u0627\u0644\u0645\u062a\u062d\u062f\u0629',
    'france': '\u0641\u0631\u0646\u0633\u0627',
    'italy': '\u0625\u064a\u0637\u0627\u0644\u064a\u0627',
    'togermany':'\u0041\u006c\u006d\u0061\u006e\u0079\u0061\u0061', 
    'togreece':'\u0041\u006c\u0079\u0075\u006e\u0061',
    'tosweden': '\u0041\u006c\u0073\u0075\u0077\u0069\u0064',
    'toaustria': '\u0041\u006c\u006e\u0061\u006d\u0073\u0061',
    'touk1': '\u0042\u0072\u0069\u0036\u0061\u006e\u0069\u0061',
    'touk2': '\u0042\u0072\u0069\u0074\u0061\u006e\u0069\u0061',
    'tofrance': '\u0046\u0072\u0061\u006e\u0073\u0061\u0061',
    'toitaly1': '\u0625\u064a\u0637\u0627\u0644\u064a\u0627',
    'toitaly2' : '\u0045\u0065\u0074\u0061\u006c\u0079\u0061',
    'toitaly3' : '\u0049\u0036\u0061\u006c\u0079\u0061',
    'toturkey': '\u0054\u0075\u0072\u006b\u0079\u0061\u0061',
    'soorya' : '\u0073\u006f\u006f\u0072\u0079\u0061',
    'tahreeb' : '\u0054\u0061\u0068\u0072\u0065\u0065\u0062',
    'tahrib' : '\u0054\u0061\u0068\u0072\u0069\u0062',
    'nihrab' :  '\u006e\u0069\u0068\u0072\u0061\u0062',
    'bahrab' :  '\u0062\u0061\u0068\u0072\u0061\u0062',
    'heribt' :  '\u0048\u0065\u0072\u0069\u0062\u0074',
    'ahrab' :  '\u0041\u0068\u0072\u0061\u0062',
    'heroob' :  '\u0048\u0065\u0072\u006f\u006f\u0062',             
    'other' :   '\u0647\u0631\u0628', 
    'other1' :   '\u0646\u0647\u0631\u0628', 
    'other2' :   '\u0628\u0647\u0631\u0628', 
    'other3' :   '\u0647\u0631\u0628\u062a', 
    'other4' :   '\u0623\u0647\u0631\u0628', 
    'other5' :   '\u0647\u0631\u0628\u0646\u0627', 
    'other6' :   '\u0647\u0631\u0648\u0628', 
    'other7' :   '\u0631\u062d\u0644\u0629 \u062d\u062a\u064a\u0631\u0629',
    'syria' : '\u0633\u0648\u0631\u064a\u0627'
                }

#Setup for accessing the Tweet stream
api = TwitterAPI(consumer_key, consumer_secret, access_token_key, access_token_secret)
r = api.request('statuses/filter', {'track': keywords.values()})

#Open file
outputfile =  open('your csv', 'w+', encoding='utf-8')
outputfile.writelines(['tid',',', 'text'])


i = 0
j = 50
    
#Looping tweets
for tweet in r:
    if 'text' not in tweet:
        continue
   # if 'coordinates' not in tweet or tweet['coordinates'] == None:
       # continue
        
    outputfile.write(tweet['id_str'])
    outputfile.write(',')
    outputfile.write(tweet['text'])
   # outputfile.write(',')
  #  outputfile.writelines(str(tweet['coordinates']['coordinates']))
   # outputfile.write(',')
    #outputfile.write(tweet['place']['country_code'])
    outputfile.write('\n')
    i += 1
    if i>j:
        break

outputfile.close()
# Out:
# Consumer and access keys and secrets added
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# W:\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     279         try:
# --> 280             return self.connection.recv_into(*args, **kwargs)
#     281         except OpenSSL.SSL.SysCallError as e:
#
# W:\Anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1624             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1625         self._raise_ssl_error(self._ssl, result)
#    1626
#
# W:\Anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1430         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1431             raise WantReadError()
#    1432         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# ...
